# %%
# !apt-get update
# !apt-get install mysql-server -y
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# !service mysql start
# Out:
#  * Starting MySQL database server mysqld
#    ...done.

# %%
# !service mysql status
# Out:
#  * /usr/bin/mysqladmin  Ver 8.0.46-0ubuntu0.22.04.2 for Linux on x86_64 ((Ubuntu))
# Copyright (c) 2000, 2026, Oracle and/or its affiliates.
#
# Oracle is a registered trademark of Oracle Corporation and/or its
# affiliates. Other names may be trademarks of their respective
# owners.
#
# Server version		8.0.46-0ubuntu0.22.04.2
# Protocol version	10
# Connection		Localhost via UNIX socket
# UNIX socket		/var/run/mysqld/mysqld.sock
# Uptime:			1 hour 3 min 24 sec
#
# Threads: 2  Questions: 20  Slow queries: 0  Opens: 130  Flush tables: 3  Open tables: 49  Queries per second avg: 0.005

# %%
pip install mysql-connector-python

# %%
import mysql.connector
conn = mysql.connector.connect(
    host = "localhost", # if using google colab : server ip/domain (host="127.0.0.1")
    user = "root",
    password = "", # workbench password # enter your own password!

)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_23966/927236393.py in <cell line: 0>()
# ----> 1 import mysql.connector
#       2 conn = mysql.connector.connect(
#       3     host = "localhost", # if using google colab : server ip/domain (host="127.0.0.1")
#       4     user = "root",
#       5     password = "", # workbench password # enter your own password!
#
# ModuleNotFoundError: No module named 'mysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !sudo mysql -e "SELECT user,host,plugin FROM mysql.user;"
# Out:
# ERROR 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)

# %%
# !sudo mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY 'root123';"
# Out:
# ERROR 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)

# %%
# !sudo service mysql start
# Out:
#  * Starting MySQL database server mysqld
#    ...done.

# %%
# !sudo mysql
# Out:
# ERROR 1045 (28000): Access denied for user 'root'@'localhost' (using password: NO)
